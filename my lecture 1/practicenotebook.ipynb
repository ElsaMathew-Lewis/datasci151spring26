# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# There are different ways of changing fonts
# Option 1 is using
# font size = 8
# The easier way is to just do
# # big text
# # slightly smaller
# # small text

# %% [markdown]
# Practicing where lecture notes will be
